# %%
# !pip install keras_sequential_ascii
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import SGD
from keras.utils import print_summary, to_categorical
import sys
import os
import matplotlib.pyplot as plt
import numpy as np
import datetime

from keras.models import Sequential
model = Sequential()
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense
from keras_sequential_ascii import sequential_model_to_ascii_printout
#Use !ls to see the current running path
# !ls
# Out:
# Collecting keras_sequential_ascii
#   Downloading https://files.pythonhosted.org/packages/2d/a4/806e3ed5d7ac7463e2fae77e09ccccc88c78266b248fb637e4efa4f65ec0/keras_sequential_ascii-0.1.1.tar.gz
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras_sequential_ascii) (2.2.4)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (1.0.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (1.11.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (1.14.6)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (1.0.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras_sequential_ascii) (3.13)
# Building wheels for collected packages: keras-sequential-ascii
# done
#   Stored in directory: /root/.cache/pip/wheels/f5/8d/81/912666dff82a923ce423a7e797cd75f54271c7031512cdb282
# Successfully built keras-sequential-ascii
# Installing collected packages: keras-sequential-ascii
# Successfully installed keras-sequential-ascii-0.1.1
# Using TensorFlow backend.
# sample_data

# %%
#If you want to change path, and upload local files. First you should upload your local files to Google drive.
#For example, upload folders "Wide-Residual-Networks-master" to Google drive folders.
#After that, run the following code to enable colab to access your Google Drive.

# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 110377 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.1-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.1-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.1-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
#Then, change the running path to Google drive
# !mkdir -p drive
# !google-drive-ocamlfuse drive

#Choose your uploaded folders
import os
os.chdir("drive/CIFAR10/Wide Residual Networks")

#Check the running path is changed.
# !ls
# Out:
# cifar10_wrn_16_8.py  plots	weights			  WRN-16-2.png
# cifar10_wrn_28_8.py  README.md	wide_residual_network.py  WRN-16-8.png

# %%
from keras.models import Model
from keras.layers import Input, Add, Activation, Dropout, Flatten, Dense
from keras.layers.convolutional import Convolution2D, MaxPooling2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras import backend as K

weight_decay = 0.0005

def initial_conv(input):
    x = Convolution2D(16, (3, 3), padding='same', kernel_initializer='he_normal',
                      W_regularizer=l2(weight_decay),
                      use_bias=False)(input)

    channel_axis = 1 if K.image_data_format() == "channels_first" else -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform')(x)
    x = Activation('relu')(x)
    return x


def expand_conv(init, base, k, strides=(1, 1)):
    x = Convolution2D(base * k, (3, 3), padding='same', strides=strides, kernel_initializer='he_normal',
                      W_regularizer=l2(weight_decay),
                      use_bias=False)(init)

    channel_axis = 1 if K.image_data_format() == "channels_first" else -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform')(x)
    x = Activation('relu')(x)

    x = Convolution2D(base * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      W_regularizer=l2(weight_decay),
                      use_bias=False)(x)

    skip = Convolution2D(base * k, (1, 1), padding='same', strides=strides, kernel_initializer='he_normal',
                      W_regularizer=l2(weight_decay),
                      use_bias=False)(init)

    m = Add()([x, skip])

    return m


def conv1_block(input, k=1, dropout=0.0):
    init = input

    channel_axis = 1 if K.image_data_format() == "channels_first" else -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform')(input)
    x = Activation('relu')(x)
    x = Convolution2D(16 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      W_regularizer=l2(weight_decay),
                      use_bias=False)(x)

    if dropout > 0.0: x = Dropout(dropout)(x)

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform')(x)
    x = Activation('relu')(x)
    x = Convolution2D(16 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      W_regularizer=l2(weight_decay),
                      use_bias=False)(x)

    m = Add()([init, x])
    return m

def conv2_block(input, k=1, dropout=0.0):
    init = input

    channel_axis = 1 if K.image_dim_ordering() == "th" else -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform')(input)
    x = Activation('relu')(x)
    x = Convolution2D(32 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      W_regularizer=l2(weight_decay),
                      use_bias=False)(x)

    if dropout > 0.0: x = Dropout(dropout)(x)

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform')(x)
    x = Activation('relu')(x)
    x = Convolution2D(32 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      W_regularizer=l2(weight_decay),
                      use_bias=False)(x)

    m = Add()([init, x])
    return m

def conv3_block(input, k=1, dropout=0.0):
    init = input

    channel_axis = 1 if K.image_dim_ordering() == "th" else -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform')(input)
    x = Activation('relu')(x)
    x = Convolution2D(64 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      W_regularizer=l2(weight_decay),
                      use_bias=False)(x)

    if dropout > 0.0: x = Dropout(dropout)(x)

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform')(x)
    x = Activation('relu')(x)
    x = Convolution2D(64 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      W_regularizer=l2(weight_decay),
                      use_bias=False)(x)

    m = Add()([init, x])
    return m

def create_wide_residual_network(input_dim, nb_classes=100, N=2, k=1, dropout=0.0, verbose=1):
    """
    Creates a Wide Residual Network with specified parameters
    :param input: Input Keras object
    :param nb_classes: Number of output classes
    :param N: Depth of the network. Compute N = (n - 4) / 6.
              Example : For a depth of 16, n = 16, N = (16 - 4) / 6 = 2
              Example2: For a depth of 28, n = 28, N = (28 - 4) / 6 = 4
              Example3: For a depth of 40, n = 40, N = (40 - 4) / 6 = 6
    :param k: Width of the network.
    :param dropout: Adds dropout if value is greater than 0.0
    :param verbose: Debug info to describe created WRN
    :return:
    """
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1

    ip = Input(shape=input_dim)

    x = initial_conv(ip)
    nb_conv = 4

    x = expand_conv(x, 16, k)
    nb_conv += 2

    for i in range(N - 1):
        x = conv1_block(x, k, dropout)
        nb_conv += 2

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform')(x)
    x = Activation('relu')(x)

    x = expand_conv(x, 32, k, strides=(2, 2))
    nb_conv += 2

    for i in range(N - 1):
        x = conv2_block(x, k, dropout)
        nb_conv += 2

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform')(x)
    x = Activation('relu')(x)

    x = expand_conv(x, 64, k, strides=(2, 2))
    nb_conv += 2

    for i in range(N - 1):
        x = conv3_block(x, k, dropout)
        nb_conv += 2

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform')(x)
    x = Activation('relu')(x)

    x = AveragePooling2D((8, 8))(x)
    x = Flatten()(x)

    x = Dense(nb_classes, W_regularizer=l2(weight_decay), activation='softmax')(x)

    model = Model(ip, x)

    if verbose: print("Wide Residual Network-%d-%d created." % (nb_conv, k))
    return model

if __name__ == "__main__":
    from keras.utils import plot_model
    from keras.layers import Input
    from keras.models import Model

    init = (32, 32, 3)

    wrn_28_10 = create_wide_residual_network(init, nb_classes=10, N=2, k=2, dropout=0.0)

#     wrn_28_10.summary()

#     plot_model(wrn_28_10, "WRN-16-2.png", show_shapes=True, show_layer_names=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", strides=(1, 1), kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), padding="same", strides=(1, 1), kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:54: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:62: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same", strides=(2, 2), kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (1, 1), padding="same", strides=(2, 2), kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:76: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:84: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same", strides=(2, 2), kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), padding="same", strides=(2, 2), kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:98: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# Wide Residual Network-16-2 created.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:106: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:165: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(10, activation="softmax", kernel_regularizer=<keras.reg...)`

# %%
import numpy as np
import sklearn.metrics as metrics

# import wide_residual_network as wrn
from keras.datasets import cifar10
import keras.callbacks as callbacks
import keras.utils.np_utils as kutils
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model

from keras import backend as K

batch_size = 128
nb_epoch = 150
img_rows, img_cols = 32, 32

(trainX, trainY), (testX, testY) = cifar10.load_data()

trainX = trainX.astype('float32')
trainX = (trainX - trainX.mean(axis=0)) / (trainX.std(axis=0))
testX = testX.astype('float32')
testX = (testX - testX.mean(axis=0)) / (testX.std(axis=0))

trainY = kutils.to_categorical(trainY)
testY = kutils.to_categorical(testY)

generator = ImageDataGenerator(rotation_range=10,
                               width_shift_range=5./32,
                               height_shift_range=5./32,)

init_shape = (3, 32, 32) if K.image_dim_ordering() == 'th' else (32, 32, 3)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 31s 0us/step

# %%
# For WRN-16-8 put N = 2, k = 8
# For WRN-28-10 put N = 4, k = 10
# For WRN-40-4 put N = 6, k = 4
model = create_wide_residual_network(init_shape, nb_classes=10, N=2, k=8, dropout=0.00)

model.summary()
plot_model(model, "WRN-16-8.png", show_shapes=False)

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["acc"])
print("Finished compiling")

#model.load_weights("weights/WRN-16-8 Weights.h5")
print("Model loaded.")

starttime = datetime.datetime.now()
model4=model.fit_generator(generator.flow(trainX, trainY, batch_size=batch_size), steps_per_epoch=len(trainX) // batch_size, epochs=nb_epoch,
                   callbacks=[callbacks.ModelCheckpoint("weights/WRN-16-8 Weights.h5",
                                                        monitor="val_acc",
                                                        save_best_only=True,
                                                        verbose=1)],
                   validation_data=(testX, testY),
                   validation_steps=testX.shape[0] // batch_size,)
endtime = datetime.datetime.now()
print (endtime - starttime)

yPreds = model.predict(testX)
yPred = np.argmax(yPreds, axis=1)
yPred = kutils.to_categorical(yPred)
yTrue = testY

scores = model.evaluate(testX, testY, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# accuracy = metrics.accuracy_score(yTrue, yPred) * 100
# error = 100 - accuracy
# print("Accuracy : ", accuracy)
# print("Error : ", error)


plt.figure(0)
plt.plot(model4.history['acc'],'salmon')
plt.plot(model4.history['val_acc'],'gold')
plt.xticks(np.arange(0, 101, 2.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Accuracy vs Validation Accuracy")
plt.legend(['train','validation'])
 
 
plt.figure(1)
plt.plot(model4.history['loss'],'salmon')
plt.plot(model4.history['val_loss'],'gold')
plt.xticks(np.arange(0, 101, 2.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
 
 
plt.show()


# Confusion matrix result
 
from sklearn.metrics import classification_report, confusion_matrix
Y_pred = model.predict(testX, verbose=2)
y_pred = np.argmax(Y_pred, axis=1)
 
for ix in range(10):
    print(ix, confusion_matrix(np.argmax(testY,axis=1),y_pred)[ix].sum())
cm = confusion_matrix(np.argmax(testY,axis=1),y_pred)
print(cm)
 
# Visualizing of confusion matrix
import seaborn as sn
import pandas  as pd
 
 
df_cm = pd.DataFrame(cm, range(10),
                  range(10))
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm,annot=True,annot_kws={"size": 12})# font size
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same", strides=(1, 1), kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), padding="same", strides=(1, 1), kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:54: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:62: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same", strides=(2, 2), kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), padding="same", strides=(2, 2), kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:76: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:84: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), padding="same", strides=(2, 2), kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (1, 1), padding="same", strides=(2, 2), kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:98: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:106: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), padding="same", kernel_initializer="he_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:165: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(10, activation="softmax", kernel_regularizer=<keras.reg...)`
# Wide Residual Network-16-8 created.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 16)   432         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 16)   64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 16)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 128)  18432       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 128)  147456      activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 128)  2048        activation_14[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 128)  0           conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 128)  512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 128)  147456      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 128)  512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 128)  147456      activation_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 128)  0           add_7[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 128)  512         add_8[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 256)  294912      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 256)  1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 16, 256)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 256)  589824      activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 256)  32768       activation_18[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 256)  0           conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 256)  1024        add_9[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 256)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 256)  589824      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 256)  1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 256)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 256)  589824      activation_21[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 256)  0           add_9[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 256)  1024        add_10[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 512)    1179648     activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 512)    2048        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 512)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 512)    2359296     activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 512)    131072      activation_22[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 512)    0           conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 512)    2048        add_11[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 512)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 512)    2359296     activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 512)    2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 512)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 512)    2359296     activation_25[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 512)    0           add_11[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 512)    2048        add_12[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 512)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 512)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 512)          0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           5130        flatten_2[0][0]
# ==================================================================================================
# Total params: 10,968,570
# Trainable params: 10,961,370
# Non-trainable params: 7,200
# __________________________________________________________________________________________________
# Finished compiling
# Model loaded.
# Epoch 1/150
# 390/390 [==============================] - 196s 503ms/step - loss: 2.0845 - acc: 0.4658 - val_loss: 1.5768 - val_acc: 0.5436
#
# Epoch 00001: val_acc improved from -inf to 0.54360, saving model to weights/WRN-16-8 Weights.h5
# Epoch 2/150
# 390/390 [==============================] - 185s 473ms/step - loss: 1.2904 - acc: 0.6321 - val_loss: 1.1960 - val_acc: 0.6682
#
# Epoch 00002: val_acc improved from 0.54360 to 0.66820, saving model to weights/WRN-16-8 Weights.h5
# Epoch 3/150
# 390/390 [==============================] - 182s 467ms/step - loss: 1.1177 - acc: 0.6894 - val_loss: 1.1553 - val_acc: 0.6925
#
# Epoch 00003: val_acc improved from 0.66820 to 0.69250, saving model to weights/WRN-16-8 Weights.h5
# Epoch 4/150
# 390/390 [==============================] - 182s 466ms/step - loss: 0.9867 - acc: 0.7411 - val_loss: 0.9943 - val_acc: 0.7520
#
# Epoch 00004: val_acc improved from 0.69250 to 0.75200, saving model to weights/WRN-16-8 Weights.h5
# Epoch 5/150
# 390/390 [==============================] - 182s 466ms/step - loss: 0.9043 - acc: 0.7690 - val_loss: 1.0416 - val_acc: 0.7382
#
# Epoch 00005: val_acc did not improve from 0.75200
# Epoch 6/150
# 390/390 [==============================] - 181s 465ms/step - loss: 0.8541 - acc: 0.7890 - val_loss: 1.0126 - val_acc: 0.7492
#
# Epoch 00006: val_acc did not improve from 0.75200
# Epoch 7/150
# 390/390 [==============================] - 181s 465ms/step - loss: 0.8069 - acc: 0.8040 - val_loss: 0.8761 - val_acc: 0.7842
#
# Epoch 00007: val_acc improved from 0.75200 to 0.78420, saving model to weights/WRN-16-8 Weights.h5
# Epoch 8/150
# 390/390 [==============================] - 181s 465ms/step - loss: 0.7787 - acc: 0.8119 - val_loss: 0.9120 - val_acc: 0.7782
#
# Epoch 00008: val_acc did not improve from 0.78420
# Epoch 9/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.7514 - acc: 0.8226 - val_loss: 0.8314 - val_acc: 0.8033
#
# Epoch 00009: val_acc improved from 0.78420 to 0.80330, saving model to weights/WRN-16-8 Weights.h5
# Epoch 10/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.7271 - acc: 0.8305 - val_loss: 0.8295 - val_acc: 0.8030
#
# Epoch 00010: val_acc did not improve from 0.80330
# Epoch 11/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.7122 - acc: 0.8346 - val_loss: 0.7639 - val_acc: 0.8220
#
# Epoch 00011: val_acc improved from 0.80330 to 0.82200, saving model to weights/WRN-16-8 Weights.h5
# Epoch 12/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.6992 - acc: 0.8397 - val_loss: 0.9085 - val_acc: 0.7834
#
# Epoch 00012: val_acc did not improve from 0.82200
# Epoch 13/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.6837 - acc: 0.8472 - val_loss: 0.8197 - val_acc: 0.8074
#
# Epoch 00013: val_acc did not improve from 0.82200
# Epoch 14/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.6763 - acc: 0.8493 - val_loss: 0.9146 - val_acc: 0.7871
#
# Epoch 00014: val_acc did not improve from 0.82200
# Epoch 15/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.6598 - acc: 0.8541 - val_loss: 0.7751 - val_acc: 0.8260
#
# Epoch 00015: val_acc improved from 0.82200 to 0.82600, saving model to weights/WRN-16-8 Weights.h5
# Epoch 16/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.6637 - acc: 0.8514 - val_loss: 0.8159 - val_acc: 0.8136
#
# Epoch 00016: val_acc did not improve from 0.82600
# Epoch 17/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.6496 - acc: 0.8562 - val_loss: 0.8400 - val_acc: 0.8123
#
# Epoch 00017: val_acc did not improve from 0.82600
# Epoch 18/150
# 390/390 [==============================] - 181s 465ms/step - loss: 0.6427 - acc: 0.8593 - val_loss: 0.7813 - val_acc: 0.8224
#
# Epoch 00018: val_acc did not improve from 0.82600
# Epoch 19/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.6403 - acc: 0.8598 - val_loss: 0.7919 - val_acc: 0.8205
#
# Epoch 00019: val_acc did not improve from 0.82600
# Epoch 20/150
# 390/390 [==============================] - 180s 463ms/step - loss: 0.6287 - acc: 0.8626 - val_loss: 0.8229 - val_acc: 0.8120
#
# Epoch 00020: val_acc did not improve from 0.82600
# Epoch 21/150
# 390/390 [==============================] - 180s 462ms/step - loss: 0.6213 - acc: 0.8668 - val_loss: 0.8561 - val_acc: 0.8086
#
# Epoch 00021: val_acc did not improve from 0.82600
# Epoch 22/150
# 390/390 [==============================] - 180s 463ms/step - loss: 0.6251 - acc: 0.8663 - val_loss: 0.7348 - val_acc: 0.8322
#
# Epoch 00022: val_acc improved from 0.82600 to 0.83220, saving model to weights/WRN-16-8 Weights.h5
# Epoch 23/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.6132 - acc: 0.8667 - val_loss: 0.8225 - val_acc: 0.8173
#
# Epoch 00023: val_acc did not improve from 0.83220
# Epoch 24/150
# 390/390 [==============================] - 180s 462ms/step - loss: 0.6103 - acc: 0.8697 - val_loss: 0.7309 - val_acc: 0.8329
#
# Epoch 00024: val_acc improved from 0.83220 to 0.83290, saving model to weights/WRN-16-8 Weights.h5
# Epoch 25/150
# 390/390 [==============================] - 180s 463ms/step - loss: 0.6064 - acc: 0.8704 - val_loss: 0.7816 - val_acc: 0.8310
#
# Epoch 00025: val_acc did not improve from 0.83290
# Epoch 26/150
# 390/390 [==============================] - 180s 463ms/step - loss: 0.6009 - acc: 0.8724 - val_loss: 0.7602 - val_acc: 0.8307
#
# Epoch 00026: val_acc did not improve from 0.83290
# Epoch 27/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5932 - acc: 0.8747 - val_loss: 0.7802 - val_acc: 0.8225
#
# Epoch 00027: val_acc did not improve from 0.83290
# Epoch 28/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5995 - acc: 0.8730 - val_loss: 0.7837 - val_acc: 0.8319
#
# Epoch 00028: val_acc did not improve from 0.83290
# Epoch 29/150
# 390/390 [==============================] - 180s 463ms/step - loss: 0.5876 - acc: 0.8757 - val_loss: 0.7624 - val_acc: 0.8287
#
# Epoch 00029: val_acc did not improve from 0.83290
# Epoch 30/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5892 - acc: 0.8765 - val_loss: 0.6894 - val_acc: 0.8503
#
# Epoch 00030: val_acc improved from 0.83290 to 0.85030, saving model to weights/WRN-16-8 Weights.h5
# Epoch 31/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5887 - acc: 0.8767 - val_loss: 0.8442 - val_acc: 0.8126
#
# Epoch 00031: val_acc did not improve from 0.85030
# Epoch 32/150
# 390/390 [==============================] - 180s 463ms/step - loss: 0.5758 - acc: 0.8819 - val_loss: 0.7563 - val_acc: 0.8354
#
# Epoch 00032: val_acc did not improve from 0.85030
# Epoch 33/150
# 390/390 [==============================] - 180s 463ms/step - loss: 0.5793 - acc: 0.8805 - val_loss: 0.7334 - val_acc: 0.8415
#
# Epoch 00033: val_acc did not improve from 0.85030
# Epoch 34/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5833 - acc: 0.8792 - val_loss: 0.7628 - val_acc: 0.8344
#
# Epoch 00034: val_acc did not improve from 0.85030
# Epoch 35/150
# 390/390 [==============================] - 180s 463ms/step - loss: 0.5664 - acc: 0.8834 - val_loss: 0.7788 - val_acc: 0.8277
#
# Epoch 00035: val_acc did not improve from 0.85030
# Epoch 36/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5698 - acc: 0.8821 - val_loss: 0.6848 - val_acc: 0.8534
#
# Epoch 00036: val_acc improved from 0.85030 to 0.85340, saving model to weights/WRN-16-8 Weights.h5
# Epoch 37/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5695 - acc: 0.8826 - val_loss: 0.7223 - val_acc: 0.8453
#
# Epoch 00037: val_acc did not improve from 0.85340
# Epoch 38/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5717 - acc: 0.8830 - val_loss: 0.7623 - val_acc: 0.8334
#
# Epoch 00038: val_acc did not improve from 0.85340
# Epoch 39/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5639 - acc: 0.8849 - val_loss: 0.7195 - val_acc: 0.8434
#
# Epoch 00039: val_acc did not improve from 0.85340
# Epoch 40/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5627 - acc: 0.8858 - val_loss: 0.7145 - val_acc: 0.8465
#
# Epoch 00040: val_acc did not improve from 0.85340
# Epoch 41/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5625 - acc: 0.8860 - val_loss: 0.7603 - val_acc: 0.8357
#
# Epoch 00041: val_acc did not improve from 0.85340
# Epoch 42/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.5607 - acc: 0.8868 - val_loss: 0.7711 - val_acc: 0.8371
#
# Epoch 00042: val_acc did not improve from 0.85340
# Epoch 43/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.5579 - acc: 0.8863 - val_loss: 0.7732 - val_acc: 0.8325
#
# Epoch 00043: val_acc did not improve from 0.85340
# Epoch 44/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.5511 - acc: 0.8896 - val_loss: 0.8013 - val_acc: 0.8297
#
# Epoch 00044: val_acc did not improve from 0.85340
# Epoch 45/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5541 - acc: 0.8876 - val_loss: 0.6822 - val_acc: 0.8540
#
# Epoch 00045: val_acc improved from 0.85340 to 0.85400, saving model to weights/WRN-16-8 Weights.h5
# Epoch 46/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.5528 - acc: 0.8875 - val_loss: 0.8092 - val_acc: 0.8269
#
# Epoch 00046: val_acc did not improve from 0.85400
# Epoch 47/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5462 - acc: 0.8894 - val_loss: 0.7470 - val_acc: 0.8487
#
# Epoch 00047: val_acc did not improve from 0.85400
# Epoch 48/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5557 - acc: 0.8859 - val_loss: 0.6463 - val_acc: 0.8653
#
# Epoch 00048: val_acc improved from 0.85400 to 0.86530, saving model to weights/WRN-16-8 Weights.h5
# Epoch 49/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.5477 - acc: 0.8903 - val_loss: 0.6955 - val_acc: 0.8487
#
# Epoch 00049: val_acc did not improve from 0.86530
# Epoch 50/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.5457 - acc: 0.8897 - val_loss: 0.7127 - val_acc: 0.8464
#
# Epoch 00050: val_acc did not improve from 0.86530
# Epoch 51/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5421 - acc: 0.8917 - val_loss: 0.7059 - val_acc: 0.8470
#
# Epoch 00051: val_acc did not improve from 0.86530
# Epoch 52/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5411 - acc: 0.8908 - val_loss: 0.6773 - val_acc: 0.8550
#
# Epoch 00052: val_acc did not improve from 0.86530
# Epoch 53/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5411 - acc: 0.8912 - val_loss: 0.7076 - val_acc: 0.8451
#
# Epoch 00053: val_acc did not improve from 0.86530
# Epoch 54/150
# 390/390 [==============================] - 180s 463ms/step - loss: 0.5440 - acc: 0.8899 - val_loss: 0.7011 - val_acc: 0.8490
#
# Epoch 00054: val_acc did not improve from 0.86530
# Epoch 55/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.5354 - acc: 0.8934 - val_loss: 0.7230 - val_acc: 0.8468
#
# Epoch 00055: val_acc did not improve from 0.86530
# Epoch 56/150
# 390/390 [==============================] - 181s 464ms/step - loss: 0.5396 - acc: 0.8923 - val_loss: 0.7430 - val_acc: 0.8397
#
# Epoch 00056: val_acc did not improve from 0.86530
# Epoch 57/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5353 - acc: 0.8925 - val_loss: 0.6873 - val_acc: 0.8574
#
# Epoch 00057: val_acc did not improve from 0.86530
# Epoch 58/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5340 - acc: 0.8946 - val_loss: 0.6694 - val_acc: 0.8569
#
# Epoch 00058: val_acc did not improve from 0.86530
# Epoch 59/150
# 390/390 [==============================] - 180s 462ms/step - loss: 0.5368 - acc: 0.8920 - val_loss: 0.6897 - val_acc: 0.8552
#
# Epoch 00059: val_acc did not improve from 0.86530
# Epoch 60/150
# 390/390 [==============================] - 181s 463ms/step - loss: 0.5352 - acc: 0.8935 - val_loss: 0.6946 - val_acc: 0.8510
#
# Epoch 00060: val_acc did not improve from 0.86530
# Epoch 61/150
# 390/390 [==============================] - 180s 462ms/step - loss: 0.5325 - acc: 0.8946 - val_loss: 0.7564 - val_acc: 0.8357
#
# Epoch 00061: val_acc did not improve from 0.86530
# Epoch 62/150
# 390/390 [==============================] - 180s 461ms/step - loss: 0.5258 - acc: 0.8959 - val_loss: 0.7770 - val_acc: 0.8307
#
# Epoch 00062: val_acc did not improve from 0.86530
# Epoch 63/150
# 390/390 [==============================] - 180s 461ms/step - loss: 0.5313 - acc: 0.8950 - val_loss: 0.6755 - val_acc: 0.8601
#
# Epoch 00063: val_acc did not improve from 0.86530
# Epoch 64/150
# 390/390 [==============================] - 180s 460ms/step - loss: 0.5249 - acc: 0.8969 - val_loss: 0.7401 - val_acc: 0.8423
#
# Epoch 00064: val_acc did not improve from 0.86530
# Epoch 65/150
# 390/390 [==============================] - 180s 460ms/step - loss: 0.5281 - acc: 0.8947 - val_loss: 0.6941 - val_acc: 0.8560
#
# Epoch 00065: val_acc did not improve from 0.86530
# Epoch 66/150
# 390/390 [==============================] - 180s 460ms/step - loss: 0.5277 - acc: 0.8950 - val_loss: 0.6726 - val_acc: 0.8624
#
# Epoch 00066: val_acc did not improve from 0.86530
# Epoch 67/150
# 390/390 [==============================] - 180s 461ms/step - loss: 0.5221 - acc: 0.8980 - val_loss: 0.6642 - val_acc: 0.8610
#
# Epoch 00067: val_acc did not improve from 0.86530
# Epoch 68/150
# 390/390 [==============================] - 179s 460ms/step - loss: 0.5224 - acc: 0.8966 - val_loss: 0.6611 - val_acc: 0.8640
#
# Epoch 00068: val_acc did not improve from 0.86530
# Epoch 69/150
# 390/390 [==============================] - 180s 460ms/step - loss: 0.5256 - acc: 0.8960 - val_loss: 0.6438 - val_acc: 0.8639
#
# Epoch 00069: val_acc did not improve from 0.86530
# Epoch 70/150
# 390/390 [==============================] - 180s 461ms/step - loss: 0.5236 - acc: 0.8970 - val_loss: 0.6960 - val_acc: 0.8517
#
# Epoch 00070: val_acc did not improve from 0.86530
# Epoch 71/150
# 390/390 [==============================] - 180s 461ms/step - loss: 0.5270 - acc: 0.8943 - val_loss: 0.7520 - val_acc: 0.8422
#
# Epoch 00071: val_acc did not improve from 0.86530
# Epoch 72/150
# 390/390 [==============================] - 179s 460ms/step - loss: 0.5192 - acc: 0.8969 - val_loss: 0.6978 - val_acc: 0.8503
#
# Epoch 00072: val_acc did not improve from 0.86530
# Epoch 73/150
# 390/390 [==============================] - 179s 460ms/step - loss: 0.5203 - acc: 0.8970 - val_loss: 0.6920 - val_acc: 0.8576
#
# Epoch 00073: val_acc did not improve from 0.86530
# Epoch 74/150
# 390/390 [==============================] - 179s 460ms/step - loss: 0.5215 - acc: 0.8970 - val_loss: 0.6637 - val_acc: 0.8574
#
# Epoch 00074: val_acc did not improve from 0.86530
# Epoch 75/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5159 - acc: 0.8985 - val_loss: 0.7451 - val_acc: 0.8419
#
# Epoch 00075: val_acc did not improve from 0.86530
# Epoch 76/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5131 - acc: 0.8987 - val_loss: 0.6991 - val_acc: 0.8513
#
# Epoch 00076: val_acc did not improve from 0.86530
# Epoch 77/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5164 - acc: 0.8997 - val_loss: 0.6823 - val_acc: 0.8559
#
# Epoch 00077: val_acc did not improve from 0.86530
# Epoch 78/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5184 - acc: 0.8982 - val_loss: 0.8061 - val_acc: 0.8289
#
# Epoch 00078: val_acc did not improve from 0.86530
# Epoch 79/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5174 - acc: 0.8966 - val_loss: 0.7052 - val_acc: 0.8512
#
# Epoch 00079: val_acc did not improve from 0.86530
# Epoch 80/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5082 - acc: 0.9003 - val_loss: 0.7227 - val_acc: 0.8494
#
# Epoch 00080: val_acc did not improve from 0.86530
# Epoch 81/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5080 - acc: 0.8999 - val_loss: 0.7291 - val_acc: 0.8421
#
# Epoch 00081: val_acc did not improve from 0.86530
# Epoch 82/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5142 - acc: 0.8981 - val_loss: 0.7399 - val_acc: 0.8439
#
# Epoch 00082: val_acc did not improve from 0.86530
# Epoch 83/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5058 - acc: 0.8999 - val_loss: 0.6916 - val_acc: 0.8530
#
# Epoch 00083: val_acc did not improve from 0.86530
# Epoch 84/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5071 - acc: 0.9018 - val_loss: 0.7905 - val_acc: 0.8336
#
# Epoch 00084: val_acc did not improve from 0.86530
# Epoch 85/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5187 - acc: 0.8985 - val_loss: 0.7057 - val_acc: 0.8530
#
# Epoch 00085: val_acc did not improve from 0.86530
# Epoch 86/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5070 - acc: 0.9009 - val_loss: 0.6572 - val_acc: 0.8654
#
# Epoch 00086: val_acc improved from 0.86530 to 0.86540, saving model to weights/WRN-16-8 Weights.h5
# Epoch 87/150
# 390/390 [==============================] - 179s 458ms/step - loss: 0.5117 - acc: 0.8994 - val_loss: 0.6436 - val_acc: 0.8642
#
# Epoch 00087: val_acc did not improve from 0.86540
# Epoch 88/150
# 390/390 [==============================] - 179s 460ms/step - loss: 0.5008 - acc: 0.9026 - val_loss: 0.6826 - val_acc: 0.8560
#
# Epoch 00088: val_acc did not improve from 0.86540
# Epoch 89/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5093 - acc: 0.8988 - val_loss: 0.7097 - val_acc: 0.8503
#
# Epoch 00089: val_acc did not improve from 0.86540
# Epoch 90/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5093 - acc: 0.8990 - val_loss: 0.6726 - val_acc: 0.8613
#
# Epoch 00090: val_acc did not improve from 0.86540
# Epoch 91/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5037 - acc: 0.9030 - val_loss: 0.7350 - val_acc: 0.8449
#
# Epoch 00091: val_acc did not improve from 0.86540
# Epoch 92/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5076 - acc: 0.9014 - val_loss: 0.6607 - val_acc: 0.8643
#
# Epoch 00092: val_acc did not improve from 0.86540
# Epoch 93/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5046 - acc: 0.9023 - val_loss: 0.7176 - val_acc: 0.8457
#
# Epoch 00093: val_acc did not improve from 0.86540
# Epoch 94/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.4998 - acc: 0.9041 - val_loss: 0.6761 - val_acc: 0.8588
#
# Epoch 00094: val_acc did not improve from 0.86540
# Epoch 95/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5053 - acc: 0.9015 - val_loss: 0.6476 - val_acc: 0.8650
#
# Epoch 00095: val_acc did not improve from 0.86540
# Epoch 96/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.4958 - acc: 0.9041 - val_loss: 0.6673 - val_acc: 0.8623
#
# Epoch 00096: val_acc did not improve from 0.86540
# Epoch 97/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5065 - acc: 0.9016 - val_loss: 0.6334 - val_acc: 0.8697
#
# Epoch 00097: val_acc improved from 0.86540 to 0.86970, saving model to weights/WRN-16-8 Weights.h5
# Epoch 98/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.4946 - acc: 0.9044 - val_loss: 0.7872 - val_acc: 0.8370
#
# Epoch 00098: val_acc did not improve from 0.86970
# Epoch 99/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5058 - acc: 0.8996 - val_loss: 0.6838 - val_acc: 0.8583
#
# Epoch 00099: val_acc did not improve from 0.86970
# Epoch 100/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5040 - acc: 0.9011 - val_loss: 0.6426 - val_acc: 0.8695
#
# Epoch 00100: val_acc did not improve from 0.86970
# Epoch 101/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.4978 - acc: 0.9027 - val_loss: 0.6990 - val_acc: 0.8532
#
# Epoch 00101: val_acc did not improve from 0.86970
# Epoch 102/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.4964 - acc: 0.9043 - val_loss: 0.6755 - val_acc: 0.8587
#
# Epoch 00102: val_acc did not improve from 0.86970
# Epoch 103/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.5014 - acc: 0.9033 - val_loss: 0.7056 - val_acc: 0.8544
#
# Epoch 00103: val_acc did not improve from 0.86970
# Epoch 104/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.4978 - acc: 0.9028 - val_loss: 0.7181 - val_acc: 0.8537
#
# Epoch 00104: val_acc did not improve from 0.86970
# Epoch 105/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.4980 - acc: 0.9030 - val_loss: 0.7048 - val_acc: 0.8538
#
# Epoch 00105: val_acc did not improve from 0.86970
# Epoch 106/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.4965 - acc: 0.9028 - val_loss: 0.6635 - val_acc: 0.8653
#
# Epoch 00106: val_acc did not improve from 0.86970
# Epoch 107/150
# 390/390 [==============================] - 179s 460ms/step - loss: 0.5001 - acc: 0.9017 - val_loss: 0.6318 - val_acc: 0.8686
#
# Epoch 00107: val_acc did not improve from 0.86970
# Epoch 108/150
# 390/390 [==============================] - 179s 458ms/step - loss: 0.4939 - acc: 0.9039 - val_loss: 0.6534 - val_acc: 0.8646
#
# Epoch 00108: val_acc did not improve from 0.86970
# Epoch 109/150
# 390/390 [==============================] - 179s 458ms/step - loss: 0.5000 - acc: 0.9028 - val_loss: 0.6839 - val_acc: 0.8558
#
# Epoch 00109: val_acc did not improve from 0.86970
# Epoch 110/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.4931 - acc: 0.9057 - val_loss: 0.6726 - val_acc: 0.8532
#
# Epoch 00110: val_acc did not improve from 0.86970
# Epoch 111/150
# 390/390 [==============================] - 179s 459ms/step - loss: 0.4980 - acc: 0.9031 - val_loss: 0.7120 - val_acc: 0.8486
#
# Epoch 00111: val_acc did not improve from 0.86970
# Epoch 112/150
# 390/390 [==============================] - 179s 458ms/step - loss: 0.4938 - acc: 0.9056 - val_loss: 0.7807 - val_acc: 0.8410
#
# Epoch 00112: val_acc did not improve from 0.86970
# Epoch 113/150
# 390/390 [==============================] - 179s 458ms/step - loss: 0.4949 - acc: 0.9051 - val_loss: 0.7211 - val_acc: 0.8468
#
# Epoch 00113: val_acc did not improve from 0.86970
# Epoch 114/150
# 390/390 [==============================] - 179s 458ms/step - loss: 0.4947 - acc: 0.9053 - val_loss: 0.6955 - val_acc: 0.8549
#
# Epoch 00114: val_acc did not improve from 0.86970
# Epoch 115/150
# 390/390 [==============================] - 179s 458ms/step - loss: 0.4950 - acc: 0.9050 - val_loss: 0.6887 - val_acc: 0.8513
#
# Epoch 00115: val_acc did not improve from 0.86970
# Epoch 116/150
# 390/390 [==============================] - 179s 458ms/step - loss: 0.4933 - acc: 0.9046 - val_loss: 0.6765 - val_acc: 0.8589
#
# Epoch 00116: val_acc did not improve from 0.86970
# Epoch 117/150
# 390/390 [==============================] - 179s 458ms/step - loss: 0.4920 - acc: 0.9045 - val_loss: 0.6639 - val_acc: 0.8604
#
# Epoch 00117: val_acc did not improve from 0.86970
# Epoch 118/150
# 390/390 [==============================] - 179s 458ms/step - loss: 0.4968 - acc: 0.9041 - val_loss: 0.6953 - val_acc: 0.8603
#
# Epoch 00118: val_acc did not improve from 0.86970
# Epoch 119/150
# 390/390 [==============================] - 178s 457ms/step - loss: 0.4847 - acc: 0.9071 - val_loss: 0.6707 - val_acc: 0.8593
#
# Epoch 00119: val_acc did not improve from 0.86970
# Epoch 120/150
# 390/390 [==============================] - 179s 458ms/step - loss: 0.4911 - acc: 0.9044 - val_loss: 0.6615 - val_acc: 0.8622
#
# Epoch 00120: val_acc did not improve from 0.86970
# Epoch 121/150
# 390/390 [==============================] - 178s 457ms/step - loss: 0.4960 - acc: 0.9038 - val_loss: 0.7673 - val_acc: 0.8408
#
# Epoch 00121: val_acc did not improve from 0.86970
# Epoch 122/150
# 390/390 [==============================] - 178s 457ms/step - loss: 0.4925 - acc: 0.9059 - val_loss: 0.6541 - val_acc: 0.8615
#
# Epoch 00122: val_acc did not improve from 0.86970
# Epoch 123/150
# 390/390 [==============================] - 178s 457ms/step - loss: 0.4879 - acc: 0.9069 - val_loss: 0.6627 - val_acc: 0.8650
#
# Epoch 00123: val_acc did not improve from 0.86970
# Epoch 124/150
# 390/390 [==============================] - 178s 457ms/step - loss: 0.4907 - acc: 0.9064 - val_loss: 0.6949 - val_acc: 0.8552
#
# Epoch 00124: val_acc did not improve from 0.86970
# Epoch 125/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4931 - acc: 0.9053 - val_loss: 0.6482 - val_acc: 0.8650
#
# Epoch 00125: val_acc did not improve from 0.86970
# Epoch 126/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4884 - acc: 0.9066 - val_loss: 0.6396 - val_acc: 0.8693
#
# Epoch 00126: val_acc did not improve from 0.86970
# Epoch 127/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4934 - acc: 0.9058 - val_loss: 0.7124 - val_acc: 0.8499
#
# Epoch 00127: val_acc did not improve from 0.86970
# Epoch 128/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4875 - acc: 0.9064 - val_loss: 0.7369 - val_acc: 0.8455
#
# Epoch 00128: val_acc did not improve from 0.86970
# Epoch 129/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4825 - acc: 0.9087 - val_loss: 0.7403 - val_acc: 0.8384
#
# Epoch 00129: val_acc did not improve from 0.86970
# Epoch 130/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4894 - acc: 0.9059 - val_loss: 0.6290 - val_acc: 0.8670
#
# Epoch 00130: val_acc did not improve from 0.86970
# Epoch 131/150
# 390/390 [==============================] - 178s 455ms/step - loss: 0.4843 - acc: 0.9068 - val_loss: 0.7290 - val_acc: 0.8482
#
# Epoch 00131: val_acc did not improve from 0.86970
# Epoch 132/150
# 390/390 [==============================] - 178s 455ms/step - loss: 0.4891 - acc: 0.9061 - val_loss: 0.7893 - val_acc: 0.8299
#
# Epoch 00132: val_acc did not improve from 0.86970
# Epoch 133/150
# 390/390 [==============================] - 177s 455ms/step - loss: 0.4871 - acc: 0.9073 - val_loss: 0.6262 - val_acc: 0.8630
#
# Epoch 00133: val_acc did not improve from 0.86970
# Epoch 134/150
# 390/390 [==============================] - 178s 455ms/step - loss: 0.4890 - acc: 0.9049 - val_loss: 0.7114 - val_acc: 0.8507
#
# Epoch 00134: val_acc did not improve from 0.86970
# Epoch 135/150
# 390/390 [==============================] - 177s 455ms/step - loss: 0.4921 - acc: 0.9048 - val_loss: 0.7954 - val_acc: 0.8388
#
# Epoch 00135: val_acc did not improve from 0.86970
# Epoch 136/150
# 390/390 [==============================] - 178s 455ms/step - loss: 0.4850 - acc: 0.9072 - val_loss: 0.6507 - val_acc: 0.8624
#
# Epoch 00136: val_acc did not improve from 0.86970
# Epoch 137/150
# 390/390 [==============================] - 178s 455ms/step - loss: 0.4912 - acc: 0.9045 - val_loss: 0.9076 - val_acc: 0.8153
#
# Epoch 00137: val_acc did not improve from 0.86970
# Epoch 138/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4820 - acc: 0.9079 - val_loss: 0.6326 - val_acc: 0.8702
#
# Epoch 00138: val_acc improved from 0.86970 to 0.87020, saving model to weights/WRN-16-8 Weights.h5
# Epoch 139/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4886 - acc: 0.9053 - val_loss: 0.6681 - val_acc: 0.8619
#
# Epoch 00139: val_acc did not improve from 0.87020
# Epoch 140/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4878 - acc: 0.9058 - val_loss: 0.8082 - val_acc: 0.8330
#
# Epoch 00140: val_acc did not improve from 0.87020
# Epoch 141/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4805 - acc: 0.9075 - val_loss: 0.6330 - val_acc: 0.8760
#
# Epoch 00141: val_acc improved from 0.87020 to 0.87600, saving model to weights/WRN-16-8 Weights.h5
# Epoch 142/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4825 - acc: 0.9065 - val_loss: 0.7008 - val_acc: 0.8539
#
# Epoch 00142: val_acc did not improve from 0.87600
# Epoch 143/150
# 390/390 [==============================] - 178s 457ms/step - loss: 0.4879 - acc: 0.9051 - val_loss: 0.6563 - val_acc: 0.8625
#
# Epoch 00143: val_acc did not improve from 0.87600
# Epoch 144/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4775 - acc: 0.9090 - val_loss: 0.7086 - val_acc: 0.8551
#
# Epoch 00144: val_acc did not improve from 0.87600
# Epoch 145/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4798 - acc: 0.9090 - val_loss: 0.6693 - val_acc: 0.8616
#
# Epoch 00145: val_acc did not improve from 0.87600
# Epoch 146/150
# 390/390 [==============================] - 178s 456ms/step - loss: 0.4772 - acc: 0.9088 - val_loss: 0.6179 - val_acc: 0.8735
#
# Epoch 00146: val_acc did not improve from 0.87600
# Epoch 147/150
# 310/390 [======================>.......] - ETA: 34s - loss: 0.4772 - acc: 0.9087
